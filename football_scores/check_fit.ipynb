# %%
import pickle
import matplotlib.pyplot as plt

with open('fit.pckl', 'rb') as f:
    fit = pickle.load(f)

# %%
fit
# Out:
# <stan.Fit>
# Parameters:
#     skills: (6,)
#     beta: ()
#     nu: ()
#     theta: ()
# Draws: 30000

# %%
fit['skills'].shape
# Out:
# (6, 30000)

# %%
fit['beta'].mean()
# Out:
# 0.8742984160112397

# %%
means = fit['skills'].mean(axis=1)
means
# Out:
# array([5.88688834, 5.84778949, 5.84503779, 4.1193602 , 4.16276631,
#        4.15918048])

# %%
plt.bar(list(range(1, 7)), means);

# %%
sns.kdeplot(fit['skills'][0][0:1000])
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
import seaborn as sns

sns.kdeplot(fit['beta'][0][0:1000])
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
fit['beta'].mean()
# Out:
# 0.8742984160112397

# %%
fit['nu'].mean()
# Out:
# 29.861164732324426

# %%
fit['theta'].mean()
# Out:
# 0.21877619587878966

# %%
sns.kdeplot(fit['theta'][0][0:1000])
# Out:
# <AxesSubplot: ylabel='Density'>
