# %%
import pickle
import matplotlib.pyplot as plt

with open('fit.pckl', 'rb') as f:
    fit = pickle.load(f)

# %%
fit['x'].shape
# Out:
# (12, 30000)

# %%
means = fit['x'].mean(axis=1)

# %%
plt.bar(list(range(1, 13)), means);

# %%
import seaborn as sns

# %%
x = fit['x'][6]
y = fit['x'][7]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y, s=0.1)

# %%
import numpy as np
np.set_printoptions(suppress=True)
np.corrcoef(fit['x'])[6]
# Out:
# array([-0.00144093, -0.00638214, -0.00020856,  0.08863066,  0.09503176,
#         0.09160936,  1.        , -0.09102021, -0.08204936, -0.00201979,
#         0.00898277, -0.00215031])

# %%
np.random.shuffle(y)
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.00559863],
#        [0.00559863, 1.        ]])

# %%
np.random.shuffle(y)
